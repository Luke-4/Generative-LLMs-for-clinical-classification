# %% [markdown]
# then finish fine tuning using Lora
# and do the classification again on all 3 datasets
# oversample 2020 using smote

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.svm import SVC

# %%
df = pd.read_json('/content/drive/MyDrive/Colab Notebooks/dissertation/data/2019_noFT.json')

#df = df.drop("Predict", axis=1)
#df['emb_biogpt_no_FineT'] = df['emb_biogpt_no_FineT'].apply(lambda x: np.array(x.split(','), dtype=float))

# Create the StandardScaler object
scaler = StandardScaler()

# %% [markdown]
# ###Classification on the Consensus column only 2 labels

# %%
# Check for consensus and mark rows for removal
rows_to_drop = []
for index, row in df.iterrows():
    if row['Consensus'] == '-' or row['Consensus'] == 'U': #or row['Consensus'] == 'U'
        rows_to_drop.append(index)

# Drop the marked rows
df = df.drop(rows_to_drop)

# Print the updated DataFrame
#print(df_2_labels)

# %%
X_biogpt, y_biogpt = df.emb_biogpt_no_FineT.tolist(), df.Consensus
X_stan, y_stan = df.emb_Stanford_no_FineT.tolist(), df.Consensus
X_llama, y_llama = df.emb_LLaMA_no_FineT.tolist(), df.Consensus

X_biogpt = np.squeeze(X_biogpt)
X_stan = np.squeeze(X_stan)
X_llama = np.squeeze(X_llama)

# %%
# Fit the scaler on the training data and transform it
X_biogpt = scaler.fit_transform(X_biogpt)
X_stan = scaler.fit_transform(X_stan)
X_llama = scaler.fit_transform(X_llama)

# %%
from sklearn.svm import SVC
#create SVC with class weight for predict column
svm_model_biogpt = SVC()
svm_model_stanford = SVC()
svm_model_llama = SVC()

# %%
def tunning(svc, X, y):
    param_grid = {'degree': [1, 2, 3],
                  'kernel': ['rbf', 'poly'],
                  'class_weight': ['balanced'],
                  'gamma':[0.01, 0.1, 1],
                  'C': [0.001, 0.1, 1]}

    grid = GridSearchCV(svc, param_grid, refit = True, verbose = 3, scoring= 'f1_macro', return_train_score=True, cv=5)

    # fitting the model for grid search
    grid.fit(X, y)

    # print best parameter after tuning
    best_params= grid.best_estimator_

    print(best_params)

    # print how our model looks after hyper-parameter tuning
    return best_params

# %%
#get best parameters for svc
svm_model_biogpt=tunning(svm_model_biogpt, X_biogpt, y_biogpt)
svm_model_stanford=tunning(svm_model_stanford, X_stan, y_stan)
svm_model_llama=tunning(svm_model_llama, X_llama, y_llama)
# Out:
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.609, test=0.378) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.605, test=0.578) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.616, test=0.579) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.695, test=0.431) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.535, test=0.552) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.893, test=0.652) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.891, test=0.732) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.878, test=0.572) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.930, test=0.644) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.872, test=0.738) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.284, test=0.269) total time=   0.1s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.357, test=0.255) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.295, test=0.269) total time=   0.1s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.395, test=0.271) total time=   0.1s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.1s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.1s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=0.956, test=0.595) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=0.926, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=0.949, test=0.525) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=0.965, test=0.504) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=0.920, test=0.504) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.893, test=0.652) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.891, test=0.732) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.878, test=0.572) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.930, test=0.644) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.872, test=0.738) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.993, test=0.646) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.986, test=0.732) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.993, test=0.572) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.527) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.986, test=0.796) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.732) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.490) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.487) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.796) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.377) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.993, test=0.646) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.986, test=0.732) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.993, test=0.572) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.527) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.986, test=0.796) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.732) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.490) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.487) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.796) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.732) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.490) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.487) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.796) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.377) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.614) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.583) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.504) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.377) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.553) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.544) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.525) total time=   0.0s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.560) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.657) total time=   0.0s
# SVC(C=0.001, class_weight='balanced', degree=1, gamma=1, kernel='poly')
# Fitting 5 folds for each of 54 candidates, totalling 270 fits
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.826, test=0.598) total time=   0.1s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.809, test=0.732) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.817, test=0.574) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.787, test=0.607) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=0.781, test=0.713) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.1s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.950, test=0.652) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.908, test=0.708) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.916, test=0.613) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.923, test=0.607) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=0.923, test=0.728) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.915, test=0.627) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.891, test=0.680) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.899, test=0.638) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.892, test=0.469) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=0.884, test=0.560) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.661) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.680) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.661) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.442) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.677) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.661) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.680) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.661) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.442) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.677) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.613) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.729) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.507) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.373) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.589) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.613) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.729) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.507) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.373) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.589) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.272, test=0.269) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.613) total time=   0.0s
# [CV 2/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.729) total time=   0.0s
# [CV 3/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.507) total time=   0.0s
# [CV 4/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.373) total time=   0.0s
# [CV 5/5] END C=0.001, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.589) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.950, test=0.652) total time=   0.0s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.908, test=0.708) total time=   0.0s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.916, test=0.613) total time=   0.0s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.923, test=0.607) total time=   0.0s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=0.923, test=0.728) total time=   0.0s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.0s
# ...
# [CV 1/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.537) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.616) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.593) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.634) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.728) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.578) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.520) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.741) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.578) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.520) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.741) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.385, test=0.387) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=0.271, test=0.275) total time=   0.1s
# [CV 1/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.578) total time=   0.1s
# [CV 2/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 3/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 4/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.520) total time=   0.1s
# [CV 5/5] END C=0.1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.741) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.579) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.696) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.672) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.607) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.668) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.579) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.696) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.672) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.607) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.668) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.579) total time=   0.0s
# [CV 2/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.696) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.672) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.607) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=1, gamma=1, kernel=poly;, score=(train=1.000, test=0.668) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.537) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.616) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.593) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.634) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.728) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.537) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.616) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.593) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.634) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.728) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.537) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.616) total time=   0.0s
# [CV 3/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.593) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.634) total time=   0.0s
# [CV 5/5] END C=1, class_weight=balanced, degree=2, gamma=1, kernel=poly;, score=(train=1.000, test=0.728) total time=   0.0s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.578) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.520) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.01, kernel=poly;, score=(train=1.000, test=0.741) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.578) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.520) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=0.1, kernel=poly;, score=(train=1.000, test=0.741) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.387) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=rbf;, score=(train=1.000, test=0.383) total time=   0.1s
# [CV 1/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.578) total time=   0.1s
# [CV 2/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 3/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.638) total time=   0.1s
# [CV 4/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.520) total time=   0.1s
# [CV 5/5] END C=1, class_weight=balanced, degree=3, gamma=1, kernel=poly;, score=(train=1.000, test=0.741) total time=   0.1s
# SVC(C=0.001, class_weight='balanced', degree=1, gamma=1, kernel='poly')

# %%
from sklearn.model_selection import cross_val_predict

#predict
y_pred_biogpt = cross_val_predict(svm_model_biogpt, X_biogpt, y_biogpt, cv=5)
y_pred_stan = cross_val_predict(svm_model_stanford, X_stan, y_stan, cv=5)
y_pred_llama = cross_val_predict(svm_model_llama, X_llama, y_llama, cv=5)

# %%
from sklearn.metrics import classification_report
print("--------------------Results 2019 on 3 labels-----------------------")
print()
print("-----------------------------Bio GPT--------------------------------")
print(classification_report(y_biogpt, y_pred_biogpt))
print("----------------------------stanford-------------------------------")
print(classification_report(y_stan, y_pred_stan))
print("-----------------------------LLaMA---------------------------------")
print(classification_report(y_llama, y_pred_llama))
# Out:
# --------------------Results 2019 on 3 labels-----------------------
#
# -----------------------------Bio GPT--------------------------------
#               precision    recall  f1-score   support
#
#            N       0.75      0.80      0.77       118
#            Y       0.61      0.54      0.58        70
#
#     accuracy                           0.70       188
#    macro avg       0.68      0.67      0.67       188
# weighted avg       0.70      0.70      0.70       188
#
# ----------------------------stanford-------------------------------
#               precision    recall  f1-score   support
#
#            N       0.74      0.78      0.76       118
#            Y       0.59      0.54      0.57        70
#
#     accuracy                           0.69       188
#    macro avg       0.67      0.66      0.66       188
# weighted avg       0.69      0.69      0.69       188
#
# -----------------------------LLaMA---------------------------------
#               precision    recall  f1-score   support
#
#            N       0.75      0.72      0.74       118
#            Y       0.56      0.60      0.58        70
#
#     accuracy                           0.68       188
#    macro avg       0.66      0.66      0.66       188
# weighted avg       0.68      0.68      0.68       188
